# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import time
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('../Data/data.csv')

# %%
#select features only
x=data.drop(['id','diagnosis','Unnamed: 32'],axis=1)
y=data['diagnosis']

# %%
x.describe()

# %% [markdown]
# #### Feature Selection using Correlation

# %% [markdown]
# The simplest method for feature selection is correlation between independent variables. Most ML models perform well when they are trained on only important features and for our case, we have 30 exploratory features. Using correlation coefficients, we can assume that variables with high correlation are redundant t a model and remain with any (arbitrary) on among them.

# %%
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
corr=x.corr()

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
# Selected column
cols_pass=x.columns[columns].to_list()
cols_dropped=x.columns[~columns].to_list()

# %%
print('Number of selected cols: {}'.format(len(cols_pass)))
cols_pass
# Out:
# Number of selected cols: 20
# ['radius_mean',
#  'texture_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
print('Number of removed cols: {}'.format(len(cols_dropped)))
cols_dropped
# Out:
# Number of removed cols: 10
# ['perimeter_mean',
#  'area_mean',
#  'concave points_mean',
#  'perimeter_se',
#  'area_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'concave points_worst']

# %% [markdown]
# By removing columns which are highly correlated (>=0.9, which is very high correlation usualy), we remain with 20 features

# %% [markdown]
# #### Tree based feature selection and random forest classification

# %% [markdown]
# The

# %%
x_new=x[cols_pass]

# %%
# split data train 80 % and test 20 %
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
def random_forest_fimportance(x_train,y_train):
    clf_rf_5 = RandomForestClassifier()      
    clr_rf_5 = clf_rf_5.fit(x_train,y_train)
    importances = clr_rf_5.feature_importances_
    indices = np.argsort(importances)[::-1]

    # Print the feature ranking
    print("Feature ranking:")

    for f in range(x_train.shape[1]):
        print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

    # Plot the feature importances of the forest

    plt.figure(1, figsize=(14, 13))
    plt.title("Feature importances")
    plt.bar(range(x_train.shape[1]), importances[indices])
    plt.xticks(range(x_train.shape[1]), x_train.columns[indices],rotation=90)
    plt.xlim([-1, x_train.shape[1]])
    plt.show()

# %%
random_forest_fimportance(x_train,y_train)
# Out:
# Feature ranking:
# 1. feature 27 (0.134349)
# 2. feature 7 (0.124185)
# 3. feature 23 (0.116538)
# 4. feature 20 (0.108810)
# 5. feature 22 (0.091809)
# 6. feature 3 (0.053656)
# 7. feature 6 (0.047127)
# 8. feature 2 (0.039253)
# 9. feature 13 (0.038682)
# 10. feature 26 (0.035788)
# 11. feature 0 (0.030780)
# 12. feature 25 (0.022579)
# 13. feature 1 (0.018328)
# 14. feature 21 (0.017293)
# 15. feature 5 (0.013801)
# 16. feature 28 (0.012682)
# 17. feature 24 (0.012427)
# 18. feature 10 (0.012249)
# 19. feature 12 (0.010616)
# 20. feature 15 (0.008783)
# 21. feature 4 (0.006990)
# 22. feature 18 (0.006117)
# 23. feature 16 (0.005462)
# 24. feature 14 (0.005353)
# 25. feature 11 (0.005134)
# 26. feature 9 (0.005096)
# 27. feature 17 (0.004366)
# 28. feature 19 (0.004203)
# 29. feature 8 (0.004157)
# 30. feature 29 (0.003388)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_new, y, test_size=0.2, random_state=42)

# %%
random_forest_fimportance(x_train1,y_train1)
# Out:
# Feature ranking:
# 1. feature 0 (0.201556)
# 2. feature 4 (0.185212)
# 3. feature 17 (0.148432)
# 4. feature 7 (0.079090)
# 5. feature 3 (0.055494)
# 6. feature 16 (0.048901)
# 7. feature 1 (0.042885)
# 8. feature 11 (0.034109)
# 9. feature 18 (0.027938)
# 10. feature 15 (0.027457)
# 11. feature 6 (0.023015)
# 12. feature 14 (0.022457)
# 13. feature 12 (0.017506)
# 14. feature 19 (0.014341)
# 15. feature 10 (0.014189)
# 16. feature 9 (0.014151)
# 17. feature 2 (0.012435)
# 18. feature 13 (0.011597)
# 19. feature 5 (0.010259)
# 20. feature 8 (0.008977)
